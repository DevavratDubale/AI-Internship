# %% [markdown]
# #Assignment 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# FOR FOLDER LINK USE THIS: https://drive.google.com/drive/folders/1r22lbY0xg4XqBQNEupzIVaLtSrbEp2HV?usp=sharing

# %%
#Create a dataframe with 4 features and 4 observation
s1= pd.Series(np.random.rand(4))
s2= pd.Series(np.random.rand(4))
s3= pd.Series(np.random.rand(4))
s4= pd.Series(np.random.rand(4))

df=pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.144767  0.497720  0.756657  0.924861
# 1  0.877275  0.328976  0.114425  0.930836
# 2  0.125630  0.466096  0.036237  0.973695
# 3  0.101499  0.886150  0.418254  0.381083

# %%
#Change column names
df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.144767        0.497720        0.756657        0.924861
# 1        0.877275        0.328976        0.114425        0.930836
# 2        0.125630        0.466096        0.036237        0.973695
# 3        0.101499        0.886150        0.418254        0.381083

# %%
#Descriptive statistics
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.312293        0.544735        0.331393        0.802619
# std          0.377070        0.239103        0.327916        0.281864
# min          0.101499        0.328976        0.036237        0.381083
# 25%          0.119597        0.431816        0.094878        0.788916
# 50%          0.135199        0.481908        0.266340        0.927848
# 75%          0.327894        0.594827        0.502855        0.941551
# max          0.877275        0.886150        0.756657        0.973695

# %%
#Check for the null values
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
#Data type of the columns
print(df['Random value 1'].dtype)
print(df['Random value 2'].dtype)
print(df['Random value 3'].dtype)
print(df['Random value 4'].dtype)
# Out:
# float64
# float64
# float64
# float64

# %%
#Display 'Random value 2' & 'Random value 3' columns with location method
loc = df.loc[:, ['Random value 2', 'Random value 3']]
print(loc)
# Out:
#    Random value 2  Random value 3
# 0        0.497720        0.756657
# 1        0.328976        0.114425
# 2        0.466096        0.036237
# 3        0.886150        0.418254

# %%
#Display the 'Random value 2' & 'Random value 3' columns with index location method
iloc = df.iloc[:, [1, 2]]
print(iloc)
# Out:
#    Random value 2  Random value 3
# 0        0.497720        0.756657
# 1        0.328976        0.114425
# 2        0.466096        0.036237
# 3        0.886150        0.418254
